# %% [markdown]
# # Adzuna Sector Job Pipeline
#
# sector-level job searches designed for the workflow:
#
# **8 sector keywords → Adzuna search → full raw payload storage → field flattening → sector hiring / noise summaries**
#
# Compared with a minimal jobs extractor, this version keeps:
# - the full raw JSON payload for each vacancy
# - flattened API fields from the Adzuna response
# - optional noise / quality signals that can be used later in scoring

# %%
import os
import json
import time
import sqlite3
from pathlib import Path
from typing import Optional

import numpy as np
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from tqdm.auto import tqdm

# %%
INPUT_PATH = Path("../output/UKcompanies_8_sectors_cleaned.csv")

OUTPUT_DIR = Path("../output/adzuna_sector_fullfield_output")
OUTPUT_DIR.mkdir(exist_ok=True)

# %%
RAW_JOBS_CSV = OUTPUT_DIR / "adzuna_sector_jobs_raw_full.csv"
SECTOR_SUMMARY_CSV = OUTPUT_DIR / "adzuna_sector_hiring_summary.csv"
CACHE_DB = OUTPUT_DIR / "adzuna_sector_cache.sqlite"

# You can set these in your environment instead of hardcoding them.
# Example:
#   export ADZUNA_APP_ID="..."
#   export ADZUNA_APP_KEY="..."
ADZUNA_APP_ID = os.getenv("ADZUNA_APP_ID", "9d40f51d").strip()
ADZUNA_APP_KEY = os.getenv("ADZUNA_APP_KEY", "6a151e5f23976ded9a47ce1cf059df04").strip()

if not ADZUNA_APP_ID or not ADZUNA_APP_KEY:
    raise ValueError("Please set ADZUNA_APP_ID and ADZUNA_APP_KEY in your environment variables.")

BASE_URL = "https://api.adzuna.com/v1/api/jobs"
COUNTRY = "gb"
WHERE_VALUE = "uk"

RESULTS_PER_PAGE = 50
MAX_PAGES_PER_QUERY = 2
REQUEST_SLEEP_SECONDS = 0.4

# Run a smaller sample first, then set this to None or a larger number.
SAMPLE_SIZE = 50

# Sector keyword map used for sector-level hiring estimation.
SECTOR_QUERY_MAP = {
    "Manufacturing": [
        "manufacturing",
        "production",
        "factory",
        "process engineer",
        "maintenance engineer",
        "manufacturing engineer",
        "production manager",
        "quality control engineer",
        "process engineer",
        "maintenance engineer",
        "manufacturing",
        "production",
        "factory",
        "process engineer",
        "maintenance engineer",
        # Expanded
        "quality assurance engineer",
        "supply chain manager manufacturing",
        "procurement manager",
        "warehouse manager",
        "lean engineer",
        "health and safety manager",
        "CNC operator",
        "logistics coordinator manufacturing",
    ],
    "Healthcare": [
        "healthcare",
        "nurse",
        "medical",
        "care worker",
        "clinical",
        # Expanded
        "physiotherapist",
        "radiographer",
        "occupational therapist",
        "GP practice manager",
        "mental health worker",
        "care home manager",
        "healthcare administrator",
        "ward manager",
        "NHS manager",
    ],
    "Technology, legal & professional": [
        "software engineer",
        "developer",
        "data analyst",
        "consultant",
        "solicitor",
         # Core professional
        "consultant",
        "solicitor",
        "management consultant",
        # Expanded tech
        "cybersecurity engineer",
        "cloud engineer",
        "DevOps engineer",
        "UX designer",
        "product owner",
        "AI engineer",
        "platform engineer",
        # Expanded professional
        "paralegal",
        "compliance officer",
        "business analyst",
    ],
    "Agriculture": [
        "agriculture",
        "farm",
        "farmer",
        "horticulture",
        "agronomist",
        "farm manager",
        "agricultural engineer",
        "horticulture manager",
        # Expanded
        "crop scientist",
        "livestock manager",
        "precision agriculture",
        "food production manager",
        "rural surveyor",
        "agricultural technician",
        "dairy farm manager",
    ],
    "Real Estate": [
        "property",
        "estate agent",
        "lettings",
        "property manager",
        "surveying",
        # Expanded
        "property developer",
        "quantity surveyor",
        "building surveyor",
        "asset manager",
        "land acquisition manager",
        "commercial property manager",
        "planning consultant",
    ],
    "Wholesale & Retail": [
        "retail",
        "sales assistant",
        "store manager",
        "wholesale",
        "merchandiser",
        "retail manager",
        "store manager",
        "merchandiser",
        "buyer wholesale",
        # Expanded
        "supply chain manager retail",
        "category manager",
        "e-commerce manager",
        "logistics manager",
        "warehouse operative",
        "stock controller",
        "visual merchandiser",
        "retail operations manager",
    ],
    "Public sector, education & charities": [
        "teacher",
        "lecturer",
        "council",
        "charity",
        "social worker",
        "local government officer",
        "fundraising",
        "local government officer",
        "charity manager",
        "lecturer",
        "council",
        "charity",
        "fundraising",
        # Expanded
        "policy officer",
        "probation officer",
        "environmental officer",
        "project coordinator charity",
        "grant manager",
        "school business manager",
        "council officer",
        "fundraising manager",
    ],
    "Fast growth & emerging sector": [
        "product manager",
        "data scientist",
        "machine learning",
        "growth marketing",
        "startup",
        "product manager tech",
        "data scientist",
        "growth manager",
        "startup operations",
        # Expanded — job role signals
        "revenue operations",
        "chief of staff startup",
        "partnerships manager",
        "AI engineer",
        "fintech product manager",
        "SaaS engineer",
        "venture capital analyst",
        # Expanded — company stage signals
        "Series A",
        "Series B",
        "scale-up",
        "deep tech",
        "biotech engineer",
        "blockchain developer",
    ],
}


TARGET_SECTORS = list(SECTOR_QUERY_MAP.keys())

# %%
# =========================================================
# Load Companies House company data
# =========================================================
df = pd.read_csv(INPUT_PATH, dtype=str)

required_cols = {"CompanyNumber", "CompanyName", "primary_sector"}
missing = required_cols - set(df.columns)
if missing:
    raise ValueError(f"Input file missing required columns: {sorted(missing)}")

df["primary_sector"] = df["primary_sector"].astype("string").str.strip()

focus_companies = df[df["primary_sector"].isin(TARGET_SECTORS)].copy()
focus_companies = (
    focus_companies[["CompanyNumber", "CompanyName", "primary_sector"]]
    .drop_duplicates()
    .head(SAMPLE_SIZE)
    .copy()
)

focus_companies.shape
# Out:
# (50, 3)

# %%
# =========================================================
# Requests session with retry support
# =========================================================
def make_session() -> requests.Session:
    session = requests.Session()
    retry = Retry(
        total=5,
        read=5,
        connect=5,
        backoff_factor=1.5,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=frozenset(["GET"]),
        raise_on_status=False,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount("https://", adapter)
    session.mount("http://", adapter)
    return session

session = make_session()

# %%
# =========================================================
# SQLite cache helpers
# =========================================================
def init_cache():
    conn = sqlite3.connect(CACHE_DB)
    cur = conn.cursor()
    cur.execute("""
        CREATE TABLE IF NOT EXISTS sector_cache (
            cache_key TEXT PRIMARY KEY,
            response_json TEXT,
            fetched_at TEXT
        )
    """)
    conn.commit()
    conn.close()

def sector_cache_key(sector_name: str, query: str, where: Optional[str], page: int) -> str:
    return f"{sector_name}|{query.lower().strip()}|{(where or '').lower().strip()}|{page}"

def cache_get(key: str) -> Optional[dict]:
    conn = sqlite3.connect(CACHE_DB)
    cur = conn.cursor()
    cur.execute("SELECT response_json FROM sector_cache WHERE cache_key = ?", (key,))
    row = cur.fetchone()
    conn.close()
    if not row:
        return None
    try:
        return json.loads(row[0])
    except Exception:
        return None

def cache_put(key: str, response: dict):
    conn = sqlite3.connect(CACHE_DB)
    cur = conn.cursor()
    cur.execute("""
        INSERT OR REPLACE INTO sector_cache (cache_key, response_json, fetched_at)
        VALUES (?, ?, datetime('now'))
    """, (key, json.dumps(response, ensure_ascii=False)))
    conn.commit()
    conn.close()

init_cache()
print("Cache initialized.")
# Out:
# Cache initialized.

# %%
# =========================================================
# Adzuna API request
# =========================================================
def adzuna_search_jobs(query: str, where: Optional[str] = None, page: int = 1, results_per_page: int = 50) -> dict:
    """
    Query the Adzuna API for job vacancies.
    """
    url = f"{BASE_URL}/{COUNTRY}/search/{page}"
    params = {
        "app_id": ADZUNA_APP_ID,
        "app_key": ADZUNA_APP_KEY,
        "what": query,
        "results_per_page": results_per_page,
        "content-type": "application/json",
    }
    if where:
        params["where"] = where

    resp = session.get(url, params=params, timeout=40)
    resp.raise_for_status()
    return resp.json()

# %%
# =========================================================
# Full payload parser + full-field extraction
# =========================================================
AGENCY_HINTS = [
    "recruitment", "recruiter", "hays", "reed", "adecco", "manpower",
    "michael page", "page personnel", "randstad", "robert walters",
    "spire", "morson", "cvlibrary", "technical recruiter"
]

GENERIC_TITLE_HINTS = [
    "assistant", "administrator", "general manager", "manager",
    "operational", "support", "operator", "assistant manager"
]

def _contains_any(text: str, keywords: list[str]) -> bool:
    text = (text or "").lower()
    return any(k.lower() in text for k in keywords)

def parse_jobs_full(data: dict, sector: str, keyword: str, page: int) -> list[dict]:
    """
    Preserve the full raw Adzuna payload while also extracting flattened fields.
    """
    rows = []

    for item in data.get("results", []):
        # Flatten nested JSON while keeping all available API keys.
        flat = pd.json_normalize(item, sep="__").to_dict(orient="records")[0]

        loc = item.get("location") or {}
        area = loc.get("area") or []

        title = str(flat.get("title", "") or "")
        desc = str(flat.get("description", "") or "")
        company_display = str((item.get("company") or {}).get("display_name", "") or "")

        salary_min = flat.get("salary_min")
        salary_max = flat.get("salary_max")
        salary_missing = pd.isna(salary_min) and pd.isna(salary_max)

        row = {
            # query metadata
            "sector": sector,
            "keyword": keyword,
            "page": page,
            "query_sector_keyword": f"{sector}::{keyword}",

            # full flattened raw payload
            **flat,

            # explicit convenience fields
            "company_display_name": company_display,
            "location_display_name": loc.get("display_name", ""),
            "location_area": " > ".join([x for x in area if x]),
            "raw_item_json": json.dumps(item, ensure_ascii=False, default=str),

            # derived quality / noise signals
            "title_len": len(title.strip()),
            "desc_len": len(desc.strip()),
            "has_salary": not salary_missing,
            "salary_missing": salary_missing,
            "location_depth": len(area),
            "possible_agency_noise": _contains_any(company_display, AGENCY_HINTS),
            "generic_title_noise": _contains_any(title, GENERIC_TITLE_HINTS),
            "keyword_in_title": keyword.lower() in title.lower(),
            "keyword_in_desc": keyword.lower() in desc.lower(),
        }

        rows.append(row)

    return rows

# %%
# =========================================================
# Fetch a single sector keyword across pages
# =========================================================
def fetch_jobs_for_sector(
    sector_name: str,
    query: str,
    where: str = WHERE_VALUE,
    max_pages: int = MAX_PAGES_PER_QUERY,
    use_cache: bool = True,
) -> pd.DataFrame:
    rows = []

    for page in range(1, max_pages + 1):
        key = sector_cache_key(sector_name, query, where, page)
        data = cache_get(key) if use_cache else None

        if data is None:
            try:
                data = adzuna_search_jobs(
                    query=query,
                    where=where,
                    page=page,
                    results_per_page=RESULTS_PER_PAGE,
                )
                if use_cache:
                    cache_put(key, data)
            except Exception as e:
                rows.append({
                    "sector": sector_name,
                    "keyword": query,
                    "page": page,
                    "error": str(e),
                })
                break

            time.sleep(REQUEST_SLEEP_SECONDS)

        results = data.get("results", []) if isinstance(data, dict) else []
        total = data.get("count", None) if isinstance(data, dict) else None

        for item in results:
            # Parse and preserve all raw payload fields
            parsed_rows = parse_jobs_full(data={"results": [item]}, sector=sector_name, keyword=query, page=page)
            if parsed_rows:
                parsed_rows[0]["adzuna_total"] = total
                rows.append(parsed_rows[0])

        if len(results) < RESULTS_PER_PAGE:
            break

    return pd.DataFrame(rows)

# %%
# =========================================================
# Batch run across all sectors / keywords
# =========================================================
def run_sector_batch(sector_query_map: dict, where: str = WHERE_VALUE) -> pd.DataFrame:
    all_raw = []

    pairs = [(sector, kw) for sector, kws in sector_query_map.items() for kw in kws]
    for sector_name, keyword in tqdm(pairs, desc="Sector keyword queries"):
        df_q = fetch_jobs_for_sector(
            sector_name=sector_name,
            query=keyword,
            where=where,
            max_pages=MAX_PAGES_PER_QUERY,
            use_cache=True,
        )

        if not df_q.empty:
            all_raw.append(df_q)

        time.sleep(REQUEST_SLEEP_SECONDS)

    raw_df = pd.concat(all_raw, ignore_index=True) if all_raw else pd.DataFrame()
    if not raw_df.empty:
        raw_df.to_csv(RAW_JOBS_CSV, index=False, encoding="utf-8-sig")

    return raw_df

# %%
# =========================================================
# Run
# =========================================================
sector_raw = run_sector_batch(SECTOR_QUERY_MAP, where=WHERE_VALUE)
print("sector_raw shape:", sector_raw.shape)
# Out:
# Sector keyword queries:   0%|          | 0/142 [00:00<?, ?it/s]
# sector_raw shape: (12660, 40)

# %%
sector_raw.head(20)
# Out:
#            sector        keyword  page          query_sector_keyword  \
# 0   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 1   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 2   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 3   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 4   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 5   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 6   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 7   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 8   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 9   Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 10  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 11  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 12  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 13  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 14  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 15  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 16  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 17  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 18  Manufacturing  manufacturing     1  Manufacturing::manufacturing
# 19  Manufacturing  manufacturing     1  Manufacturing::manufacturing
#
#    contract_type   latitude  salary_max  \
# 0      permanent  51.080127    49836.43
# 1            NaN  53.757702    49556.15
# 2            NaN  53.480701    45532.82
# 3            NaN  53.754200    51775.75
# 4            NaN  53.758495    43891.34
# 5            NaN  53.798801    44280.07
# 6       contract  51.620399    47659.41
# 7      permanent  52.647999    55000.00
# 8      permanent        NaN    44273.44
# 9      permanent  51.403702    35000.00
# 10      contract  51.752300   104000.00
# 11     permanent  53.383099    50000.00
# 12      contract        NaN    47823.77
# 13     permanent  51.017899    35000.00
# 14     permanent        NaN    45000.00
# 15     permanent  53.033495         NaN
# 16      contract  51.941399    27040.00
# 17      contract  52.489201    27476.00
# 18     permanent  54.236645    40858.94
# 19           NaN  54.448101    50000.00
#
#                                                 adref  \
# 0   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc2MjcxNjkwMCIsI...
# 1   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 2   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTcyNDgxNTI4MiIsI...
# 3   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 4   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 5   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 6   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTcwNzMzMTA5NyIsI...
# 7   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc1MTI2OTg5NyIsI...
# 8   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc0NDQ4NjM2OCIsI...
# 9   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 10  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTcyNzg4NzcyNiIsI...
# 11  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc3MDMzMjAyNSIsI...
# 12  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 13  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc0MDMyNzYyMCIsI...
# 14  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 15  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 16  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 17  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc0ODg2NzM5MCIsI...
# 18  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 19  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
#
#                      __CLASS__  \
# 0   Adzuna::API::Response::Job
# 1   Adzuna::API::Response::Job
# 2   Adzuna::API::Response::Job
# 3   Adzuna::API::Response::Job
# 4   Adzuna::API::Response::Job
# 5   Adzuna::API::Response::Job
# 6   Adzuna::API::Response::Job
# 7   Adzuna::API::Response::Job
# 8   Adzuna::API::Response::Job
# 9   Adzuna::API::Response::Job
# 10  Adzuna::API::Response::Job
# 11  Adzuna::API::Response::Job
# 12  Adzuna::API::Response::Job
# 13  Adzuna::API::Response::Job
# 14  Adzuna::API::Response::Job
# 15  Adzuna::API::Response::Job
# 16  Adzuna::API::Response::Job
# 17  Adzuna::API::Response::Job
# 18  Adzuna::API::Response::Job
# 19  Adzuna::API::Response::Job
#
#                                           description  ... desc_len  \
# 0   Management Accountant - Manufacturing, Permane...  ...      500
# 1   Financial Controller job, Manufacturing sector...  ...      500
# 2   Work in a broad role in a growing business You...  ...      500
# 3   Job Title: Manufacturing Engineer – Electrical...  ...      500
# 4   Job Title: Manufacturing Engineer – Electrical...  ...      500
# 5   Job Title: Manufacturing Engineer – Electrical...  ...      500
# 6   12 month contract for Manufacturing Accountant...  ...      500
# 7   Manufacturing Engineer A recognised high volum...  ...      500
# 8   This is an excellent opportunity for a Estimat...  ...      500
# 9   Location: Thatcham, Berkshire Department: Manu...  ...      500
# 10  My client, an innovative company at the cuttin...  ...      500
# 11  REED Engineering & Manufacturing are working w...  ...      500
# 12  Mydas Recruitment are experts in the sourcing ...  ...      500
# 13  Buyer (Manufacturing) £30,000 - £35,000  6% Pe...  ...      500
# 14  Manufacturing Engineer (Equipment Maintenance)...  ...      500
# 15  Multiple Manufacturing Operative & Finishing R...  ...      500
# 16  Installation, Manufacturing & Warehouse Techni...  ...      500
# 17  Job Title: Experienced Window & Door Fabricato...  ...      500
# 18  Position Title: Manufacturing Technician Posit...  ...      500
# 19  Manufacturing Engineer Location: Northern Irel...  ...      500
#
#     has_salary salary_missing  location_depth possible_agency_noise  \
# 0         True          False               3                  True
# 1         True          False               4                  True
# 2         True          False               4                  True
# 3         True          False               5                 False
# 4         True          False               5                 False
# 5         True          False               5                 False
# 6         True          False               3                  True
# 7         True          False               4                 False
# 8         True          False               3                 False
# 9         True          False               4                 False
# 10        True          False               4                 False
# 11        True          False               4                  True
# 12        True          False               3                  True
# 13        True          False               4                  True
# 14        True          False               1                 False
# 15        True          False               5                 False
# 16        True          False               4                  True
# 17        True          False               4                 False
# 18        True          False               5                 False
# 19        True          False               3                  True
#
#    generic_title_noise keyword_in_title keyword_in_desc adzuna_total  \
# 0                False             True            True        53539
# 1                False             True            True        53539
# 2                 True             True            True        53539
# 3                False             True            True        53539
# 4                False             True            True        53539
# 5                False             True            True        53539
# 6                False             True            True        53539
# 7                False             True            True        53539
# 8                False             True            True        53539
# 9                False             True            True        53539
# 10               False             True            True        53539
# 11               False             True            True        53539
# 12               False             True            True        53539
# 13               False             True            True        53539
# 14               False             True            True        53539
# 15               False             True            True        53539
# 16               False             True            True        53539
# 17               False             True            True        53539
# 18               False             True            True        53539
# 19               False             True            True        53539
#
#    contract_time
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8      full_time
# 9      full_time
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16     full_time
# 17     full_time
# 18     full_time
# 19           NaN
#
# [20 rows x 40 columns]

# %%
# =========================================================
# Build sector summary — Hiring Score + Signal Quality
# =========================================================


AGENCY_HINTS = [
    "recruitment", "recruiter", "hays", "reed", "adecco", "manpower",
    "michael page", "page personnel", "randstad", "robert walters",
    "spire", "morson", "cvlibrary", "technical recruiter"
]

GENERIC_TITLE_HINTS = [
    "assistant", "administrator", "general manager", "manager",
    "operational", "support", "operator", "assistant manager"
]

def _contains_any(text: str, keywords: list) -> bool:
    text = (text or "").lower()
    return any(k.lower() in text for k in keywords)


def _minmax(series: pd.Series) -> pd.Series:
    """Min-max -- [0, 1]"""
    mn, mx = series.min(), series.max()
    if mx == mn:
        return pd.Series([0.5] * len(series), index=series.index)
    return (series - mn) / (mx - mn)


def build_sector_hiring_summary(raw_df: pd.DataFrame) -> pd.DataFrame:
    if raw_df.empty:
        return pd.DataFrame()

    out = raw_df.copy()

    
    if "job_id" not in out.columns:
        out["job_id"] = out["id"] if "id" in out.columns else pd.NA

    
    out = out.drop_duplicates(subset=["sector", "job_id"]).copy()

    
    def _to_naive(series):
        dt = pd.to_datetime(series, errors="coerce")
        try:
            if dt.dt.tz is not None:
                dt = dt.dt.tz_localize(None)
        except Exception:
            pass
        return dt

    out["created_dt"]  = _to_naive(out.get("created",  pd.Series(dtype=str)))
    out["modified_dt"] = _to_naive(out.get("modified", pd.Series(dtype=str)))
    now = pd.Timestamp.now()

    if "possible_agency_noise" not in out.columns:
        out["possible_agency_noise"] = out.get(
            "company_display_name", pd.Series([""] * len(out))
        ).apply(lambda x: _contains_any(str(x), AGENCY_HINTS))

    if "generic_title_noise" not in out.columns:
        out["generic_title_noise"] = out.get(
            "title", pd.Series([""] * len(out))
        ).apply(lambda x: _contains_any(str(x), GENERIC_TITLE_HINTS))

    if "salary_missing" not in out.columns:
        out["salary_missing"] = (
            out.get("salary_min", pd.Series([np.nan]*len(out))).isna() &
            out.get("salary_max", pd.Series([np.nan]*len(out))).isna()
        )

    if "desc_len" not in out.columns:
        out["desc_len"] = out.get(
            "description", pd.Series([""] * len(out))
        ).apply(lambda x: len(str(x or "").strip()))

    if "contract_time" not in out.columns:
        out["contract_time"] = ""

    agg = (
        out.groupby("sector", dropna=False)
        .agg(
            raw_rows               = ("job_id",                "size"),
            unique_jobs            = ("job_id",                "nunique"),
            vacancy_count          = ("job_id",                "nunique"),
            unique_titles          = ("title",                 "nunique"),
            unique_locations       = ("location_display_name", "nunique"),
            query_coverage         = ("keyword",               "nunique"),
            latest_job_update      = ("modified_dt",           "max"),
            earliest_job_post      = ("created_dt",            "min"),
            
            agency_noise_ratio     = ("possible_agency_noise", "mean"),
            generic_noise_ratio    = ("generic_title_noise",   "mean"),
            salary_missing_ratio   = ("salary_missing",        "mean"),
            short_desc_ratio       = ("desc_len",              lambda s: (s < 120).mean()),
            parttime_ratio         = ("contract_time",         lambda s: (s.str.lower() == "part_time").mean()),
        )
        .reset_index()
    )

    
    agg["duplicate_ratio"] = (
        1 - agg["unique_jobs"] / agg["raw_rows"].clip(lower=1)
    )

    
    agg["days_since_latest"] = (
        (now - agg["latest_job_update"]).dt.days.fillna(999)
    )

    
    # 权重：volume 40% | recency 25% | coverage 20% | breadth 15%
    agg["volume_norm"]   = _minmax(agg["vacancy_count"])
    agg["recency_norm"]  = 1 - _minmax(agg["days_since_latest"].clip(upper=180))
    agg["coverage_norm"] = _minmax(
        0.5 * _minmax(agg["query_coverage"]) +
        0.5 * _minmax(agg["unique_titles"])
    )
    agg["breadth_norm"]  = _minmax(agg["unique_locations"])

    agg["sector_hiring_score"] = (
        0.40 * agg["volume_norm"]   +
        0.25 * agg["recency_norm"]  +
        0.20 * agg["coverage_norm"] +
        0.15 * agg["breadth_norm"]
    ).mul(100).round(1)

   
    top_title_share = (
        out.groupby("sector")["title"]
        .apply(lambda g: g.value_counts().iloc[0] / len(g) if len(g) > 0 else 0)
        .reset_index()
        .rename(columns={"title": "title_concentration"})
    )
    agg = agg.merge(top_title_share, on="sector", how="left")

    agg["noise_score"] = (
        0.35 * agg["agency_noise_ratio"].fillna(0)    +
        0.25 * agg["generic_noise_ratio"].fillna(0)   +
        0.20 * agg["salary_missing_ratio"].fillna(0)  +
        0.10 * agg["parttime_ratio"].fillna(0)        +
        0.10 * agg["title_concentration"].fillna(0)
    ).mul(100).round(1)

    # hiring_signal_quality：（0–100） 
    agg["hiring_signal_quality"] = (100 - agg["noise_score"]).round(1)

    return agg

# %%
sector_summary = build_sector_hiring_summary(sector_raw)
sector_summary.to_csv(SECTOR_SUMMARY_CSV, index=False, encoding="utf-8-sig")

print(f"sector_summary -- {SECTOR_SUMMARY_CSV}")
print(f"  sectors CNT: {len(sector_summary)}")
print()

display_cols = [
    "sector", "vacancy_count", "query_coverage",
    "unique_titles", "unique_locations", "days_since_latest",
    "sector_hiring_score", "noise_score", "hiring_signal_quality"
]
sector_summary[display_cols].sort_values("sector_hiring_score", ascending=False)
# Out:
# sector_summary -- ../output/adzuna_sector_fullfield_output/adzuna_sector_hiring_summary.csv
#   sectors CNT: 8
#                                  sector  vacancy_count  query_coverage  \
# 1         Fast growth & emerging sector           1615              20
# 3                         Manufacturing           1485              16
# 6      Technology, legal & professional           1595              16
# 4  Public sector, education & charities           1395              15
# 2                            Healthcare           1302              14
# 7                    Wholesale & Retail           1297              15
# 0                           Agriculture            884              15
# 5                           Real Estate           1019              12
#
#    unique_titles  unique_locations  days_since_latest  sector_hiring_score  \
# 1           1032               369              999.0                 72.5
# 3            506               693              999.0                 66.8
# 6            545               490              999.0                 64.1
# 4            864               598              999.0                 62.1
# 2            476               672              999.0                 52.9
# 7            451               650              999.0                 52.4
# 0            576               477              999.0                 23.8
# 5            416               444              999.0                 23.4
#
#    noise_score  hiring_signal_quality
# 1         13.5                   86.5
# 3         21.6                   78.4
# 6          8.2                   91.8
# 4         15.2                   84.8
# 2         20.2                   79.8
# 7         21.1                   78.9
# 0         18.3                   81.7
# 5         20.5                   79.5

# %%
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

weight_scenarios = {
    "Literature-based ": [0.40, 0.25, 0.20, 0.15],
    "Equal weight ":   [0.25, 0.25, 0.25, 0.25],
    "Volume-heavy":              [0.55, 0.20, 0.15, 0.10],
    "Recency-heavy":             [0.20, 0.50, 0.20, 0.10],
}

dims = ["volume_norm", "recency_norm", "coverage_norm", "breadth_norm"]

scores_df = pd.DataFrame({
    name: sum(w * sector_summary[d] for w, d in zip(weights, dims)) * 100
    for name, weights in weight_scenarios.items()
})
scores_df.index = sector_summary["sector"]

# Spearman
print("=== Spearman matrix（> 0.85）===\n")
names = list(weight_scenarios.keys())
corr_rows = []
for s1 in names:
    row = {}
    for s2 in names:
        r, _ = spearmanr(scores_df[s1], scores_df[s2])
        row[s2] = round(r, 3)
    corr_rows.append(row)
corr_matrix = pd.DataFrame(corr_rows, index=names)
print(corr_matrix.to_string())

fig, ax = plt.subplots(figsize=(13, 5))
x = np.arange(len(sector_summary))
width = 0.2
colors = ["steelblue", "darkorange", "seagreen", "mediumpurple"]

for i, (name, weights) in enumerate(weight_scenarios.items()):
    score = sum(w * sector_summary[d] for w, d in zip(weights, dims)) * 100
    ax.bar(x + i*width, score, width=width, label=name,
           color=colors[i], alpha=0.85, edgecolor="white")

ax.set_xticks(x + 1.5*width)
ax.set_xticklabels(sector_summary["sector"], rotation=25, ha="right", fontsize=9)
ax.set_ylabel("Sector Hiring Score")
ax.set_title("Sensitivity Analysis: Rankings Under 4 Weight Scenarios")
ax.legend(fontsize=8)
plt.tight_layout()
# plt.savefig(OUTPUT_DIR / "sensitivity_analysis.png", bbox_inches="tight", dpi=120)
plt.show()
# Out:
# === Spearman matrix（> 0.85）===
#
#                    Literature-based   Equal weight   Volume-heavy  Recency-heavy
# Literature-based               1.000          0.952         0.952          0.952
# Equal weight                   0.952          1.000         0.857          0.952
# Volume-heavy                   0.952          0.857         1.000          0.881
# Recency-heavy                  0.952          0.952         0.881          1.000

# %%
sector_raw
# Out:
#                               sector               keyword  page  \
# 0                      Manufacturing         manufacturing     1
# 1                      Manufacturing         manufacturing     1
# 2                      Manufacturing         manufacturing     1
# 3                      Manufacturing         manufacturing     1
# 4                      Manufacturing         manufacturing     1
# ...                              ...                   ...   ...
# 12655  Fast growth & emerging sector  blockchain developer     1
# 12656  Fast growth & emerging sector  blockchain developer     1
# 12657  Fast growth & emerging sector  blockchain developer     1
# 12658  Fast growth & emerging sector  blockchain developer     1
# 12659  Fast growth & emerging sector  blockchain developer     1
#
#                                     query_sector_keyword contract_type  \
# 0                           Manufacturing::manufacturing     permanent
# 1                           Manufacturing::manufacturing           NaN
# 2                           Manufacturing::manufacturing           NaN
# 3                           Manufacturing::manufacturing           NaN
# 4                           Manufacturing::manufacturing           NaN
# ...                                                  ...           ...
# 12655  Fast growth & emerging sector::blockchain deve...           NaN
# 12656  Fast growth & emerging sector::blockchain deve...           NaN
# 12657  Fast growth & emerging sector::blockchain deve...           NaN
# 12658  Fast growth & emerging sector::blockchain deve...           NaN
# 12659  Fast growth & emerging sector::blockchain deve...           NaN
#
#         latitude  salary_max  \
# 0      51.080127    49836.43
# 1      53.757702    49556.15
# 2      53.480701    45532.82
# 3      53.754200    51775.75
# 4      53.758495    43891.34
# ...          ...         ...
# 12655  51.503378    75111.68
# 12656        NaN    75154.38
# 12657  51.503378    75748.95
# 12658  51.503378   100845.33
# 12659  51.503378    82032.98
#
#                                                    adref  \
# 0      eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc2MjcxNjkwMCIsI...
# 1      eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 2      eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTcyNDgxNTI4MiIsI...
# 3      eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# 4      eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMkxmYXZ4MXY4UkdGa...
# ...                                                  ...
# 12655  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZUNHTk9jbC04UkdaR...
# 12656  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZUNHTk9jbC04UkdaR...
# 12657  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZUNHTk9jbC04UkdaR...
# 12658  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZUNHTk9jbC04UkdaR...
# 12659  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZUNHTk9jbC04UkdaR...
#
#                         __CLASS__  \
# 0      Adzuna::API::Response::Job
# 1      Adzuna::API::Response::Job
# 2      Adzuna::API::Response::Job
# 3      Adzuna::API::Response::Job
# 4      Adzuna::API::Response::Job
# ...                           ...
# 12655  Adzuna::API::Response::Job
# 12656  Adzuna::API::Response::Job
# 12657  Adzuna::API::Response::Job
# 12658  Adzuna::API::Response::Job
# 12659  Adzuna::API::Response::Job
#
#                                              description  ... desc_len  \
# 0      Management Accountant - Manufacturing, Permane...  ...      500
# 1      Financial Controller job, Manufacturing sector...  ...      500
# 2      Work in a broad role in a growing business You...  ...      500
# 3      Job Title: Manufacturing Engineer – Electrical...  ...      500
# 4      Job Title: Manufacturing Engineer – Electrical...  ...      500
# ...                                                  ...  ...      ...
# 12655  About Wintermute Wintermute is a technology un...  ...      500
# 12656  The engineering team at Chainalysis is inspire...  ...      500
# 12657  At Ripple, we’re building a world where value ...  ...      500
# 12658  About Wintermute Wintermute is one of the larg...  ...      500
# 12659  Blockchain is connecting the world to the futu...  ...      500
#
#        has_salary salary_missing  location_depth possible_agency_noise  \
# 0            True          False               3                  True
# 1            True          False               4                  True
# 2            True          False               4                  True
# 3            True          False               5                 False
# 4            True          False               5                 False
# ...           ...            ...             ...                   ...
# 12655        True          False               2                 False
# 12656        True          False               1                 False
# 12657        True          False               2                 False
# 12658        True          False               2                 False
# 12659        True          False               2                 False
#
#       generic_title_noise keyword_in_title keyword_in_desc adzuna_total  \
# 0                   False             True            True        53539
# 1                   False             True            True        53539
# 2                    True             True            True        53539
# 3                   False             True            True        53539
# 4                   False             True            True        53539
# ...                   ...              ...             ...          ...
# 12655                True            False           False           35
# 12656                True            False           False           35
# 12657                True            False           False           35
# 12658               False            False           False           35
# 12659               False            False           False           35
#
#       contract_time
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 12655     full_time
# 12656     full_time
# 12657     full_time
# 12658     full_time
# 12659     full_time
#
# [12660 rows x 40 columns]

# %%
sector_raw.columns
# Out:
# Index(['sector', 'keyword', 'page', 'query_sector_keyword', 'contract_type',
#        'latitude', 'salary_max', 'adref', '__CLASS__', 'description',
#        'salary_is_predicted', 'longitude', 'redirect_url', 'salary_min', 'id',
#        'created', 'title', 'category__label', 'category__tag',
#        'category____CLASS__', 'location__area', 'location____CLASS__',
#        'location__display_name', 'company__display_name', 'company____CLASS__',
#        'company_display_name', 'location_display_name', 'location_area',
#        'raw_item_json', 'title_len', 'desc_len', 'has_salary',
#        'salary_missing', 'location_depth', 'possible_agency_noise',
#        'generic_title_noise', 'keyword_in_title', 'keyword_in_desc',
#        'adzuna_total', 'contract_time'],
#       dtype='object')

# %%
# =========================================================
# Merge sector scores back to company table
# =========================================================
merge_cols = [
    "sector",
    "vacancy_count",
    "unique_jobs",
    "unique_titles",
    "unique_locations",
    "query_coverage",
    "latest_job_update",
    "days_since_latest",
    "sector_hiring_score",    
    "noise_score",            
    "hiring_signal_quality",  
]

company_enriched = df.merge(
    sector_summary[merge_cols],
    left_on="primary_sector",
    right_on="sector",
    how="left"
)
company_enriched = company_enriched.drop(columns=["sector"])


company_enriched["hiring_score"] = company_enriched["sector_hiring_score"]

# missing sector
company_enriched["hiring_score"]           = company_enriched["hiring_score"].fillna(0)
company_enriched["hiring_signal_quality"]  = company_enriched["hiring_signal_quality"].fillna(50)


print(
    company_enriched.groupby("primary_sector")[["hiring_score", "hiring_signal_quality"]]
    .first()
    .sort_values("hiring_score", ascending=False)
    .to_string()
)
# Out:
#                                       hiring_score  hiring_signal_quality
# primary_sector
# Fast growth & emerging sector                 72.5                   86.5
# Manufacturing                                 66.8                   78.4
# Technology, legal & professional              64.1                   91.8
# Public sector, education & charities          62.1                   84.8
# Healthcare                                    52.9                   79.8
# Wholesale & Retail                            52.4                   78.9
# Agriculture                                   23.8                   81.7
# Real Estate                                   23.4                   79.5

# %%
# =========================================================
# Export company-level output
# =========================================================
OUT_PATH = OUTPUT_DIR / "companies_with_sector_hiring.csv"

company_enriched.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")

# %%
# =========================================================
# Optional full run
# =========================================================
# If the sample looks good, run on the full dataset:
#
# focus_companies_full = df[df["primary_sector"].isin(TARGET_SECTORS)].copy()
# sector_raw_full = run_sector_batch(SECTOR_QUERY_MAP, where=WHERE_VALUE)
# sector_summary_full = build_sector_hiring_summary(sector_raw_full)
# sector_summary_full.to_csv(SECTOR_SUMMARY_CSV, index=False, encoding="utf-8-sig")
# company_enriched_full = df.merge(
#     sector_summary_full[
#         [
#             "sector",
#             "vacancy_count",
#             "unique_jobs",
#             "unique_titles",
#             "unique_locations",
#             "query_coverage",
#             "latest_job_update",
#             "earliest_job_post",
#             "days_since_created",
#             "sector_hiring_score",
#             "noise_score",
#         ]
#     ],
#     left_on="primary_sector",
#     right_on="sector",
#     how="left"
# ).drop(columns=["sector"])
# company_enriched_full["hiring_score"] = company_enriched_full["sector_hiring_score"]
# company_enriched_full.to_csv(
#     OUTPUT_DIR / "companies_with_sector_hiring_full_payload_fullrun.csv",
#     index=False,
#     encoding="utf-8-sig"
# )
