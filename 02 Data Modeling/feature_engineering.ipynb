# %%
import pandas as pd
from pathlib import Path
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 01

# %%
financial_data_01 = pd.read_csv("../01 EDA + Data PreProcessing/04_Five_CSV/01_financial_status_labels_100k.csv")

# %%
financial_data_01_sample = financial_data_01.sample(n=1000, random_state=42)

# %%
financial_data_01_sample.head()
# Out:
#       CompanyNumber_norm                          CompanyName  \
# 75721           11153083                   LARWIN ESTATES LTD
# 80184           13431081          EMPORIUM OF WONDERS LIMITED
# 19864           10472899  GREEN HOME ENERGY (PRIVATE) LIMITED
# 76699           10800893                   GROWTH GORILLA LTD
# 92991           11377376                       VAQUOI LIMITED
#
#                          primary_sector Accounts_AccountCategory  \
# 75721                       Real Estate             MICRO ENTITY
# 80184                Wholesale & Retail     TOTAL EXEMPTION FULL
# 19864  Technology, legal & professional             MICRO ENTITY
# 76699  Technology, legal & professional     TOTAL EXEMPTION FULL
# 92991  Technology, legal & professional             MICRO ENTITY
#
#       latest_period_end latest_available_date financial_evidence_tier  \
# 75721        2024-01-31            2024-10-31   T2_balance_sheet_rich
# ...

# %%
financial_data_01_sample.to_csv("../output/samples/01_financial_status_labels_100k_sample.csv", index=False)

# %% [markdown]
# ## 02

# %%
financial_data_02 = pd.read_csv("../01 EDA + Data PreProcessing/04_Five_CSV/02_financial_scale_labels_100k.csv")

# %%
financial_data_02_sample = financial_data_02.sample(n=1000, random_state=42)

# %%
financial_data_02_sample.head()
# Out:
#       CompanyNumber_norm                          CompanyName  \
# 75721           11153083                   LARWIN ESTATES LTD
# 80184           13431081          EMPORIUM OF WONDERS LIMITED
# 19864           10472899  GREEN HOME ENERGY (PRIVATE) LIMITED
# 76699           10800893                   GROWTH GORILLA LTD
# 92991           11377376                       VAQUOI LIMITED
#
#                          primary_sector Accounts_AccountCategory  \
# 75721                       Real Estate             MICRO ENTITY
# 80184                Wholesale & Retail     TOTAL EXEMPTION FULL
# 19864  Technology, legal & professional             MICRO ENTITY
# 76699  Technology, legal & professional     TOTAL EXEMPTION FULL
# 92991  Technology, legal & professional             MICRO ENTITY
#
#       latest_period_end latest_available_date financial_evidence_tier  \
# 75721        2024-01-31            2024-10-31   T2_balance_sheet_rich
# ...

# %%
financial_data_02_sample.to_csv("../output/samples/02_financial_scale_labels_100k_sample.csv", index=False)

# %% [markdown]
# ## 03

# %%
financial_data_03 = pd.read_csv("../01 EDA + Data PreProcessing/04_Five_CSV/03_financial_change_labels.csv")
# Out:
# C:\Users\86132\AppData\Local\Temp\ipykernel_3020\364946345.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   financial_data_03 = pd.read_csv("../01 EDA + Data PreProcessing/04_Five_CSV/03_financial_change_labels.csv")

# %%
financial_data_03_sample = financial_data_03.sample(n=1000, random_state=42)

# %%
financial_data_03_sample.head()
# Out:
#       CompanyNumber_norm                       CompanyName  \
# 64119           13955543      ALPHA UK INVESTMENTS LIMITED
# 68035           14390075           CR WENTWORTH PT LIMITED
# 53647           12765519                       MYLEE'S LTD
# 49880           12316478     SOUTH CUMBRIAN PROPERTIES LTD
# 13810            5962404  SAINT ANDREWS PROPERTIES LIMITED
#
#                          primary_sector Accounts_AccountCategory    period_t  \
# 64119                       Real Estate     TOTAL EXEMPTION FULL  2024-03-31
# 68035  Technology, legal & professional             MICRO ENTITY  2024-09-26
# 53647                Wholesale & Retail     TOTAL EXEMPTION FULL  2024-07-31
# 49880                       Real Estate             MICRO ENTITY  2023-11-30
# 13810                       Real Estate     TOTAL EXEMPTION FULL  2023-10-31
#
#       period_t_plus_1 available_date_t available_date_t_plus_1  gap_days  \
# ...

# %%
financial_data_03_sample.to_csv("../output/samples/03_financial_change_labels_sample.csv", index=False)

# %% [markdown]
# ## 03 new

# %%
financial_data_03_new_path = Path(r"E:\files\Bristol\project\记录\data\finance\03_financial_change_labels.csv")

# %%
financial_data_03_new = pd.read_csv(financial_data_03_new_path)
# Out:
# C:\Users\86132\AppData\Local\Temp\ipykernel_24204\2921774310.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   financial_data_03_new = pd.read_csv(financial_data_03_new_path)

# %%
financial_data_03_new_sample = financial_data_03_new.sample(n=1000, random_state=42)

# %%
financial_data_03_new_sample.head()
# Out:
#       CompanyNumber_norm                       CompanyName  \
# 64119           13955543      ALPHA UK INVESTMENTS LIMITED
# 68035           14390075           CR WENTWORTH PT LIMITED
# 53647           12765519                       MYLEE'S LTD
# 49880           12316478     SOUTH CUMBRIAN PROPERTIES LTD
# 13810            5962404  SAINT ANDREWS PROPERTIES LIMITED
#
#                          primary_sector Accounts_AccountCategory    period_t  \
# 64119                       Real Estate     TOTAL EXEMPTION FULL  2024-03-31
# 68035  Technology, legal & professional             MICRO ENTITY  2024-09-26
# 53647                Wholesale & Retail     TOTAL EXEMPTION FULL  2024-07-31
# 49880                       Real Estate             MICRO ENTITY  2023-11-30
# 13810                       Real Estate     TOTAL EXEMPTION FULL  2023-10-31
#
#       period_t_plus_1 available_date_t available_date_t_plus_1  gap_days  \
# ...

# %%
financial_data_03_new_sample.to_csv("../output/samples/03_financial_change_labels_new_sample.csv", index=False)

# %% [markdown]
# ## 04

# %%
financial_data_04 = pd.read_csv("../01 EDA + Data PreProcessing/04_Five_CSV/04_financial_transition_labels.csv")
# Out:
# C:\Users\86132\AppData\Local\Temp\ipykernel_24864\824491810.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   financial_data_04 = pd.read_csv("../01 EDA + Data PreProcessing/04_Five_CSV/04_financial_transition_labels.csv")

# %%
financial_data_04_sample = financial_data_04.sample(n=1000, random_state=42)

# %%
financial_data_04_sample.head()
# Out:
#       CompanyNumber_norm                       CompanyName  \
# 64119           13955543      ALPHA UK INVESTMENTS LIMITED
# 68035           14390075           CR WENTWORTH PT LIMITED
# 53647           12765519                       MYLEE'S LTD
# 49880           12316478     SOUTH CUMBRIAN PROPERTIES LTD
# 13810            5962404  SAINT ANDREWS PROPERTIES LIMITED
#
#                          primary_sector Accounts_AccountCategory    period_t  \
# 64119                       Real Estate     TOTAL EXEMPTION FULL  2024-03-31
# 68035  Technology, legal & professional             MICRO ENTITY  2024-09-26
# 53647                Wholesale & Retail     TOTAL EXEMPTION FULL  2024-07-31
# 49880                       Real Estate             MICRO ENTITY  2023-11-30
# 13810                       Real Estate     TOTAL EXEMPTION FULL  2023-10-31
#
#       period_t_plus_1 available_date_t available_date_t_plus_1  gap_days  \
# ...

# %%
financial_data_04_sample.to_csv("../output/samples/04_financial_transittion_labels_sample.csv", index=False)

# %% [markdown]
# ## 05

# %%
financial_data_05 = pd.read_csv("../01 EDA + Data PreProcessing/04_Five_CSV/05_financial_data_quality_labels_100k.csv")

# %%
financial_data_05_sample = financial_data_05.sample(n=1000, random_state=42)

# %%
financial_data_05_sample.head()
# Out:
#       CompanyNumber_norm                          CompanyName  \
# 75721           11153083                   LARWIN ESTATES LTD
# 80184           13431081          EMPORIUM OF WONDERS LIMITED
# 19864           10472899  GREEN HOME ENERGY (PRIVATE) LIMITED
# 76699           10800893                   GROWTH GORILLA LTD
# 92991           11377376                       VAQUOI LIMITED
#
#                          primary_sector Accounts_AccountCategory  \
# 75721                       Real Estate             MICRO ENTITY
# 80184                Wholesale & Retail     TOTAL EXEMPTION FULL
# 19864  Technology, legal & professional             MICRO ENTITY
# 76699  Technology, legal & professional     TOTAL EXEMPTION FULL
# 92991  Technology, legal & professional             MICRO ENTITY
#
#       latest_period_end latest_available_date financial_evidence_tier  \
# 75721        2024-01-31            2024-10-31   T2_balance_sheet_rich
# ...

# %%
financial_data_05_sample.to_csv("../output/samples/05_financial_data_quality_labels_sample.csv", index=False)

# %% [markdown]
# ## hiring

# %%
hiring_100k_path = Path(r"E:\files\Bristol\project\记录\data\hiring\hiring_100k.csv")
company_hiring_path = Path(r"E:\files\Bristol\project\记录\data\hiring\company_hiring_score.csv")

# %%
hiring_01 = pd.read_csv(hiring_100k_path)

# %%
hiring_01_sample = hiring_01.sample(n=1000, random_state=42)

# %%
hiring_01_sample.head()
# Out:
#       CompanyNumber                          CompanyName  \
# 75721      11153083                   LARWIN ESTATES LTD
# 80184      13431081          EMPORIUM OF WONDERS LIMITED
# 19864      10472899  GREEN HOME ENERGY (PRIVATE) LIMITED
# 76699      10800893                   GROWTH GORILLA LTD
# 92991      11377376                       VAQUOI LIMITED
#
#                          primary_sector CompanyStatus  company_age_years  \
# 75721                       Real Estate        Active                8.4
# 80184                Wholesale & Retail        Active                5.1
# 19864  Technology, legal & professional        Active                9.6
# 76699  Technology, legal & professional        Active                9.1
# 92991  Technology, legal & professional        Active                8.1
#
#       Accounts_AccountCategory  sector_hiring_score  status_factor  \
# 75721             MICRO ENTITY                 23.4            1.0
# ...

# %%
hiring_01_sample.to_csv("../output/samples/hiring_100k_sample.csv", index=False)

# %% [markdown]
# ### company hiring

# %%
hiring_02 = pd.read_csv(company_hiring_path)
# Out:
# C:\Users\86132\AppData\Local\Temp\ipykernel_21580\4242448751.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   hiring_02 = pd.read_csv(company_hiring_path)

# %%
hiring_02.shape
# Out:
# (3415689, 15)

# %%
hiring_02_sample = hiring_02.sample(n=1000, random_state=42)

# %%
hiring_02_sample.head()
# Out:
#         CompanyNumber                         CompanyName  \
# 2436424      15958424        SHEFFORD SWIM SCHOOL LIMITED
# 2011331      14646234                 12 GORE TERRACE LTD
# 2225587      15382322                FORESIGHT COMMON LTD
# 559156        7376902  LITTLE WEAVERS DAY NURSERY LIMITED
# 2038068      14737885                           IVCHI LTD
#
#                                primary_sector CompanyStatus  \
# 2436424  Public sector, education & charities        Active
# 2011331                           Real Estate        Active
# 2225587                           Real Estate        Active
# 559156   Public sector, education & charities        Active
# 2038068      Technology, legal & professional        Active
#
#          company_age_years Accounts_AccountCategory  sector_hiring_score  \
# 2436424                1.8             MICRO ENTITY                 68.7
# 2011331                3.4     TOTAL EXEMPTION FULL                 20.8
# ...

# %%
hiring_02_sample.to_csv("../output/samples/company_hiring_score_sample.csv", index=False)

# %%
hiring_02_sample['sector_hiring_score'].unique()
# Out:
# array([68.7, 20.8, 66.9, 58. , 65.7, 72.4, 66.7, 44.9])

# %%
hiring_02_sample['hiring_signal_quality'].unique()
# Out:
# array([89.7, 73.6, 90.1, 80.6, 85.9, 78.3, 84.5])

# %% [markdown]
# ## companies House

# %%
ch = pd.read_csv("../01 EDA + Data PreProcessing/01_CompaniesSelected/UKcompanies_active_account_category_sample_100k.csv")

# %%
ch_sample = ch.sample(n=1000, random_state=42)

# %%
ch_sample.head()
# Out:
#       CompanyNumber                          CompanyName CompanyStatus  \
# 75721      11153083                   LARWIN ESTATES LTD        Active
# 80184      13431081          EMPORIUM OF WONDERS LIMITED        Active
# 19864      10472899  GREEN HOME ENERGY (PRIVATE) LIMITED        Active
# 76699      10800893                   GROWTH GORILLA LTD        Active
# 92991      11377376                       VAQUOI LIMITED        Active
#
#                CompanyCategory CountryOfOrigin RegAddress_Country  \
# 75721  Private Limited Company  United Kingdom            ENGLAND
# 80184  Private Limited Company  United Kingdom     UNITED KINGDOM
# 19864  Private Limited Company  United Kingdom            ENGLAND
# 76699  Private Limited Company  United Kingdom     UNITED KINGDOM
# 92991  Private Limited Company  United Kingdom            ENGLAND
#
#       RegAddress_PostTown RegAddress_PostCode IncorporationDate  \
# 75721            HOUNSLOW             TW4 7QJ        2018-01-16
# ...

# %%
ch_sample.to_csv("../output/samples/UKcompaniesHouse_100k_sample.csv", index=False)
